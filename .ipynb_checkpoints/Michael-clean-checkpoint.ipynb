# %% [markdown]
# <h2>Initializing</h2>
# <p>Import Libraries, add variables for attribute strings (to save '') and load data</p>

# %%
import pandas as pd
import numpy as np
from scipy.stats.stats import pearsonr
from sklearn.cluster import KMeans
from sklearn import preprocessing
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors.nearest_centroid import NearestCentroid
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix 
from sklearn import tree
from sklearn.metrics import classification_report
from scipy import interp
from sklearn.metrics import accuracy_score
from sklearn.utils.multiclass import unique_labels
import math

fixed_acidity = 'fixed acidity'
volatile_acidity = 'volatile acidity'
citric_acid = 'citric acid'
residual_sugar = 'residual sugar'
chlorides = 'chlorides'
free_sulfur_dioxide = 'free sulfur dioxide'
total_sulfur_dioxide = 'total sulfur dioxide'
density = 'density'
ph = 'pH'
sulphates = 'sulphates'
alcohol = 'alcohol'
quality = 'quality'
qclass = 'qclass'
ratio_to_fixed = 'ratio_to_fixed'
ratio_to_volatile = 'ratio_to_volatile'
ph_acidity = 'ph_acidity'
ratio_to_ph = 'ratio_to_ph'

# %%
def confusion_matrix_report(y_true, y_pred):
    cm, labels = confusion_matrix(y_true, y_pred), unique_labels(y_true, y_pred)
    column_width = max([len(str(x)) for x in labels] + [5])  # 5 is value length
    report = " " * column_width + " " + "{:_^{}}".format("Prediction", column_width * len(labels))+ "\n"
    report += " " * column_width + " ".join(["{:>{}}".format(label, column_width) for label in labels]) + "\n"
    for i, label1 in enumerate(labels):
        report += "{:>{}}".format(label1, column_width) + " ".join(["{:{}d}".format(cm[i, j], column_width) for j in range(len(labels))]) + "\n"
    return report
def root_mean_squared_error(y_true, y_pred):
        return math.sqrt(math.mean(math.square(y_pred - y_true), axis=-1))

# %% [markdown]
# <p>Import red and white dataset.<br/>
# Split into input matrix (independent vars) and output vector (target vars).<br/>
# </p>

# %% [markdown]
# <p>sort for kNN (https://scikit-learn.org/stable/modules/neighbors.html#unsupervised-nearest-neighbors) </p>

# %%
white = pd.read_csv("data/winequality-white1.csv")
red = pd.read_csv("data/winequality-red1.csv")
white.sort_values(by='quality',inplace=True)
red.sort_values(by='quality',inplace=True)
white_target = white[quality]
red_target = red[quality]
white_input = white.drop(quality,axis=1)
red_input = red.drop(quality,axis=1)

# %% [markdown]
# Add ratio of acidity to sugar as attribute.

# %%
#white[ph_acidity] = 7 - white[ph]
#red[ph_acidity] = 7 - red[ph]
#white_input[ratio_to_fixed]=white[residual_sugar]/white[fixed_acidity]
#white_input[ratio_to_volatile]=white[residual_sugar]/white[volatile_acidity]
#white_input[ratio_to_ph]=white[residual_sugar]/white[ph_acidity]
#red_input[ratio_to_fixed]=red[residual_sugar]/red[fixed_acidity]
#red_input[ratio_to_volatile]=red[residual_sugar]/red[volatile_acidity]
#red_input[ratio_to_ph]=red[residual_sugar]/red[ph_acidity]

# %% [markdown]
# <p>using log.</p>

# %%
log_white_norm=np.log(white_input+1)
log_red_norm=np.log(red_input+1)
f_log_white=log_white_norm.drop([fixed_acidity,sulphates,chlorides,citric_acid,ph,density,total_sulfur_dioxide,residual_sugar],axis=1)
f_log_red=log_red_norm.drop([free_sulfur_dioxide,ph,residual_sugar,chlorides,citric_acid,fixed_acidity,density],axis=1)

# %% [markdown]
# <p>Normalize using MinMax Normalizer.</p>

# %%
mm_white_norm=(white_input-white_input.min())/(white_input.max()-white_input.min())
mm_red_norm=(red_input-red_input.min())/(red_input.max()-red_input.min())
f_mm_white = mm_white_norm.drop([fixed_acidity,sulphates,chlorides,citric_acid,ph,density,total_sulfur_dioxide,residual_sugar],axis=1)
f_mm_red = mm_red_norm.drop([free_sulfur_dioxide,ph,residual_sugar,chlorides,citric_acid,fixed_acidity,density],axis=1)

# %% [markdown]
# <p>Normalize using Mean Normalizer.</p>

# %%
white_norm=(white_input-white_input.mean())/(white_input.std())
red_norm=(red_input-red_input.mean())/(red_input.std())

# %% [markdown]
# <p>Correlation Matrices</p>

# %%
wcorr = white.corr()
wcorr.style.background_gradient().set_precision(3)
# Out:
# <style  type="text/css" >
#     #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow0_col0 {
#             background-color:  #023858;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow0_col1 {
#             background-color:  #e8e4f0;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow0_col2 {
#             background-color:  #a1bbda;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow0_col3 {
#             background-color:  #a7bddb;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow0_col4 {
#             background-color:  #c5cce3;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow0_col5 {
#             background-color:  #e4e1ef;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow0_col6 {
#             background-color:  #a7bddb;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow0_col7 {
#             background-color:  #4897c4;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow0_col8 {
#             background-color:  #fff7fb;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow0_col9 {
#             background-color:  #fdf5fa;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow0_col10 {
#             background-color:  #a8bedc;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow0_col11 {
#             background-color:  #e7e3f0;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow1_col0 {
#             background-color:  #c5cce3;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow1_col1 {
#             background-color:  #023858;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow1_col2 {
#             background-color:  #fdf5fa;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow1_col3 {
#             background-color:  #adc1dd;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow1_col4 {
#             background-color:  #b9c6e0;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow1_col5 {
#             background-color:  #ede7f2;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow1_col6 {
#             background-color:  #a7bddb;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow1_col7 {
#             background-color:  #86b0d3;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow1_col8 {
#             background-color:  #c8cde4;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow1_col9 {
#             background-color:  #fff7fb;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow1_col10 {
#             background-color:  #7eadd1;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow1_col11 {
#             background-color:  #f2ecf5;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow2_col0 {
#             background-color:  #73a9cf;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow2_col1 {
#             background-color:  #faf2f8;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow2_col2 {
#             background-color:  #023858;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow2_col3 {
#             background-color:  #a5bddb;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow2_col4 {
#             background-color:  #afc1dd;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow2_col5 {
#             background-color:  #c8cde4;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow2_col6 {
#             background-color:  #9fbad9;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow2_col7 {
#             background-color:  #69a5cc;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow2_col8 {
#             background-color:  #dfddec;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow2_col9 {
#             background-color:  #f1ebf4;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow2_col10 {
#             background-color:  #9ebad9;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow2_col11 {
#             background-color:  #d5d5e8;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow3_col0 {
#             background-color:  #abbfdc;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow3_col1 {
#             background-color:  #d8d7e9;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow3_col2 {
#             background-color:  #d7d6e9;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow3_col3 {
#             background-color:  #023858;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow3_col4 {
#             background-color:  #b5c4df;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow3_col5 {
#             background-color:  #8cb3d5;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow3_col6 {
#             background-color:  #4897c4;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow3_col7 {
#             background-color:  #03517e;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow3_col8 {
#             background-color:  #e4e1ef;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow3_col9 {
#             background-color:  #fef6fa;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow3_col10 {
#             background-color:  #dfddec;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow3_col11 {
#             background-color:  #e4e1ef;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow4_col0 {
#             background-color:  #bbc7e0;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow4_col1 {
#             background-color:  #d7d6e9;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow4_col2 {
#             background-color:  #d2d3e7;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow4_col3 {
#             background-color:  #a7bddb;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow4_col4 {
#             background-color:  #023858;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow4_col5 {
#             background-color:  #c6cce3;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow4_col6 {
#             background-color:  #89b1d4;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow4_col7 {
#             background-color:  #4a98c5;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow4_col8 {
#             background-color:  #d3d4e7;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow4_col9 {
#             background-color:  #f8f1f8;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow4_col10 {
#             background-color:  #d3d4e7;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow4_col11 {
#             background-color:  #f4edf6;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow5_col0 {
#             background-color:  #cccfe5;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow5_col1 {
#             background-color:  #f3edf5;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow5_col2 {
#             background-color:  #d7d6e9;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow5_col3 {
#             background-color:  #6ba5cd;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow5_col4 {
#             background-color:  #b3c3de;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow5_col5 {
#             background-color:  #023858;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow5_col6 {
#             background-color:  #0a73b2;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow5_col7 {
#             background-color:  #4094c3;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow5_col8 {
#             background-color:  #c0c9e2;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow5_col9 {
#             background-color:  #f1ebf5;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow5_col10 {
#             background-color:  #c0c9e2;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow5_col11 {
#             background-color:  #d2d3e7;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow6_col0 {
#             background-color:  #abbfdc;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow6_col1 {
#             background-color:  #d3d4e7;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow6_col2 {
#             background-color:  #d2d2e7;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow6_col3 {
#             background-color:  #4897c4;
#         }    #T_130a29d4_f0ac_11e8_8251_5ce0c5fe058crow6_col4 {

# %%
rcorr = red.corr()
rcorr.style.background_gradient().set_precision(3)
# Out:
# <style  type="text/css" >
#     #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow0_col0 {
#             background-color:  #023858;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow0_col1 {
#             background-color:  #dedcec;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow0_col2 {
#             background-color:  #0569a5;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow0_col3 {
#             background-color:  #dfddec;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow0_col4 {
#             background-color:  #c5cce3;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow0_col5 {
#             background-color:  #fff7fb;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow0_col6 {
#             background-color:  #f4edf6;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow0_col7 {
#             background-color:  #056ba7;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow0_col8 {
#             background-color:  #fff7fb;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow0_col9 {
#             background-color:  #adc1dd;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow0_col10 {
#             background-color:  #c2cbe2;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow0_col11 {
#             background-color:  #a8bedc;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow1_col0 {
#             background-color:  #d0d1e6;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow1_col1 {
#             background-color:  #023858;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow1_col2 {
#             background-color:  #fff7fb;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow1_col3 {
#             background-color:  #f3edf5;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow1_col4 {
#             background-color:  #cdd0e5;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow1_col5 {
#             background-color:  #ede7f2;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow1_col6 {
#             background-color:  #d4d4e8;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow1_col7 {
#             background-color:  #b0c2de;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow1_col8 {
#             background-color:  #5ea0ca;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow1_col9 {
#             background-color:  #fff7fb;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow1_col10 {
#             background-color:  #dcdaeb;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow1_col11 {
#             background-color:  #fff7fb;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow2_col0 {
#             background-color:  #0566a0;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow2_col1 {
#             background-color:  #fff7fb;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow2_col2 {
#             background-color:  #023858;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow2_col3 {
#             background-color:  #d9d8ea;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow2_col4 {
#             background-color:  #a8bedc;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow2_col5 {
#             background-color:  #f3edf5;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow2_col6 {
#             background-color:  #dbdaeb;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow2_col7 {
#             background-color:  #4e9ac6;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow2_col8 {
#             background-color:  #f2ecf5;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow2_col9 {
#             background-color:  #86b0d3;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow2_col10 {
#             background-color:  #9ab8d8;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow2_col11 {
#             background-color:  #8bb2d4;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow3_col0 {
#             background-color:  #7eadd1;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow3_col1 {
#             background-color:  #acc0dd;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow3_col2 {
#             background-color:  #89b1d4;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow3_col3 {
#             background-color:  #023858;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow3_col4 {
#             background-color:  #d0d1e6;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow3_col5 {
#             background-color:  #c1cae2;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow3_col6 {
#             background-color:  #b3c3de;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow3_col7 {
#             background-color:  #529bc7;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow3_col8 {
#             background-color:  #adc1dd;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow3_col9 {
#             background-color:  #d9d8ea;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow3_col10 {
#             background-color:  #abbfdc;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow3_col11 {
#             background-color:  #c2cbe2;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow4_col0 {
#             background-color:  #83afd3;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow4_col1 {
#             background-color:  #9ebad9;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow4_col2 {
#             background-color:  #79abd0;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow4_col3 {
#             background-color:  #ebe6f2;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow4_col4 {
#             background-color:  #023858;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow4_col5 {
#             background-color:  #e9e5f1;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow4_col6 {
#             background-color:  #d9d8ea;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow4_col7 {
#             background-color:  #81aed2;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow4_col8 {
#             background-color:  #d1d2e6;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow4_col9 {
#             background-color:  #73a9cf;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow4_col10 {
#             background-color:  #dfddec;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow4_col11 {
#             background-color:  #dedcec;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow5_col0 {
#             background-color:  #bbc7e0;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow5_col1 {
#             background-color:  #afc1dd;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow5_col2 {
#             background-color:  #b9c6e0;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow5_col3 {
#             background-color:  #d0d1e6;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow5_col4 {
#             background-color:  #d9d8ea;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow5_col5 {
#             background-color:  #023858;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow5_col6 {
#             background-color:  #0f76b3;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow5_col7 {
#             background-color:  #b9c6e0;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow5_col8 {
#             background-color:  #89b1d4;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow5_col9 {
#             background-color:  #d1d2e6;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow5_col10 {
#             background-color:  #c4cbe3;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow5_col11 {
#             background-color:  #d2d2e7;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow6_col0 {
#             background-color:  #b3c3de;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow6_col1 {
#             background-color:  #9ab8d8;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow6_col2 {
#             background-color:  #a5bddb;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow6_col3 {
#             background-color:  #cacee5;
#         }    #T_1320db76_f0ac_11e8_b905_5ce0c5fe058crow6_col4 {

# %% [markdown]
# <h2>Assigning classes</h2>
# <p>
#     Assign classes based on quality. Less than 6; 6; better than 6. Because it makes sense considering the distribution of ratings.
# </p>

# %%
#Assign classes for white
conditions = [(white['quality'] < 6),
              (white['quality'] > 6)]
choices = ['2_low', '1_high']
white['class'] = np.select(conditions, choices, default = '3_medium')
choices = [1,3]
white['classnum'] = np.select(conditions, choices, default = 2)
white_classnum = white['classnum']
white.drop('classnum',axis=1,inplace=True)
#Assign classes for red
conditions = [(red['quality'] < 6),
              (red['quality'] > 6)]
choices = ['3_low', '1_high']
red['class'] = np.select(conditions, choices, default = '2_medium')
choices = [1,3]
red['classnum'] = np.select(conditions, choices, default = 2)
red_classnum = red['classnum']
red.drop('classnum',axis=1,inplace=True)

#print('class distribution fot white:')
#print(white['class'].value_counts())
#print('\n class distribution for red:')
#print(red['class'].value_counts())

white_norm['class']=white['class']
red_norm['class']=red['class']

white_targetclass = white_classnum
red_targetclass = red_classnum
print(white_targetclass.value_counts())
print(red_targetclass.value_counts())
#white_targetclass = white['class']
#red_targetclass = red['class']
# Out:
# 2    2198
# 1    1640
# 3    1060
# Name: classnum, dtype: int64
# 1    744
# 2    638
# 3    217
# Name: classnum, dtype: int64

# %%
white_norm_input = white_norm.drop('class', axis = 1)
red_norm_input = red_norm.drop('class', axis = 1)

# %%
#white_norm.loc[white_norm['class']=='3_high'].describe()
#white_norm.loc[white_norm['class']=='2_medium'].describe()
#white_norm.loc[white_norm['class']=='1_low'].describe()
white_norm_filtered = white_norm_input.drop([fixed_acidity,sulphates,chlorides,citric_acid,ph,density,total_sulfur_dioxide,residual_sugar],axis=1)
white_norm_filtered.describe()
# Out:
#        volatile acidity  free sulfur dioxide       alcohol
# count      4.898000e+03         4.898000e+03  4.898000e+03
# mean      -1.998539e-14        -6.380722e-17 -4.325046e-14
# std        1.000000e+00         1.000000e+00  1.000000e+00
# min       -1.966784e+00        -1.958477e+00 -2.043089e+00
# 25%       -6.770318e-01        -7.237012e-01 -8.241915e-01
# 50%       -1.809733e-01        -7.691388e-02 -9.285319e-02
# 75%        4.142970e-01         6.286722e-01  7.197450e-01
# max        8.152811e+00         1.491679e+01  2.995020e+00

# %%
#red_norm.loc[red_norm['class']=='3_high'].describe()
#red_norm.loc[red_norm['class']=='2_medium'].describe()
#red_norm.loc[red_norm['class']=='1_low'].describe()
red_norm_filtered = red_norm_input.drop([free_sulfur_dioxide,ph,residual_sugar,chlorides,citric_acid,fixed_acidity,density],axis=1)
red_norm_filtered.describe()
# Out:
#        volatile acidity  total sulfur dioxide     sulphates       alcohol
# count      1.599000e+03          1.599000e+03  1.599000e+03  1.599000e+03
# mean       8.477896e-15          2.365560e-16  6.625737e-15  2.204136e-14
# std        1.000000e+00          1.000000e+00  1.000000e+00  1.000000e+00
# min       -2.277567e+00         -1.230199e+00 -1.935902e+00 -1.898325e+00
# 25%       -7.696903e-01         -7.438076e-01 -6.380200e-01 -8.661079e-01
# 50%       -4.367545e-02         -2.574163e-01 -2.250577e-01 -2.092427e-01
# 75%        6.264921e-01          4.721707e-01  4.238832e-01  6.352984e-01
# max        5.876138e+00          7.372847e+00  7.916200e+00  4.201138e+00

# %% [markdown]
# <h2>k-NN classification<h2><p>https://scikit-learn.org/stable/tutorial/statistical_inference/supervised_learning.html#the-curse-of-dimensionality</p>

# %% [markdown]
# <h3>white: normalized and selected for attributes with low std/range</h3>

# %%
def run_knn_report(inputs, targets):
    print("_______________________________________________________________________________________________")
    print("KNN, no weights")
    for n_neighbour in range(1,21):
        print(str(n_neighbour) + " neighbours:")
        knn_estimator = KNeighborsClassifier(n_neighbour)
        print(str(n_neighbour)+ " neighbours//")
        predicted = cross_val_predict(knn_estimator,inputs,targets,cv=cv)
        print(confusion_matrix_report(targets,predicted))
        print(classification_report(targets,predicted))
        try:
            print("RMSE:")
            print(root_mean_squared_error(targets,predicted))
        except(Error):
            pass
    
cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=1337)
#cv = KFold(n_splits=3)
run_knn_report(white_norm_filtered.values, white_targetclass)
# Out:
# _______________________________________________________________________________________________
# KNN, no weights
# 1 neighbours:
# 1 neighbours//
#       __Prediction___
#          1     2     3
#     1 1120   419   101
#     2  420  1444   334
#     3   84   326   650
#
#              precision    recall  f1-score   support
#
#           1       0.69      0.68      0.69      1640
#           2       0.66      0.66      0.66      2198
#           3       0.60      0.61      0.61      1060
#
# avg / total       0.66      0.66      0.66      4898
#
# RMSE:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-3b8edcaca46a> in run_knn_report(inputs, targets)
#      12             print("RMSE:")
# ---> 13             print(root_mean_squared_error(targets,predicted))
#      14         except(Error):
#
# <ipython-input-2-0ae642049bdc> in root_mean_squared_error(y_true, y_pred)
#       9 def root_mean_squared_error(y_true, y_pred):
# ---> 10         return sqrt(mean(square(y_pred - y_true), axis=-1))
#
# NameError: name 'sqrt' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-3b8edcaca46a> in <module>()
#      17 cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=1337)
#      18 #cv = KFold(n_splits=3)
# ---> 19 run_knn_report(white_norm_filtered.values, white_targetclass)
#
# <ipython-input-14-3b8edcaca46a> in run_knn_report(inputs, targets)
#      12             print("RMSE:")
#      13             print(root_mean_squared_error(targets,predicted))
# ---> 14         except(Error):
#      15             pass
#      16
#
# NameError: name 'Error' is not defined

# %% [markdown]
# <h3><i>red: </i>normalized and selected for attributes with low std/range</h3>

# %%
run_knn_report(red_norm_filtered.values,red_targetclass)

# %% [markdown]
# <h3>white: normalized unselected</h3>

# %%
run_knn_report(white_norm_input.values,white_targetclass)

# %% [markdown]
# <h3><i>red: </i> normalized unselected</h3>

# %%
run_knn_report(red_norm_input.values,red_targetclass)

# %% [markdown]
# <h3> white: unfiltered, unnormalized <h3>

# %%
run_knn_report(white_input.values,white_targetclass)

# %% [markdown]
# <h3>red, unnormalized, unselected</h3>

# %%
run_knn_report(red_input.values,red_targetclass)

# %%
def run_knc_report(inputs, targets):
    knc_estimator = NearestCentroid()
    predicted = cross_val_predict(knc_estimator,inputs,targets,cv=cv)
    print(confusion_matrix_report(targets,predicted))
    print(classification_report(targets,predicted))
    try:
        print("RMSE:")
        print(root_mean_squared_error(targets,predicted))
    except(Error):
        pass

# %%
run_knc_report(white_norm_input.values,white_targetclass)

# %%
run_knc_report(red_norm_input.values,red_targetclass)

# %%
def run_kncs_report(inputs, targets,thresh=0):
    knc_estimator = NearestCentroid(shrink_threshold=thresh)
    predicted = cross_val_predict(knc_estimator,inputs,targets,cv=cv)
    print(confusion_matrix_report(targets,predicted))
    print(classification_report(targets,predicted))

# %%
run_kncs_report(white_norm_input.values,white_targetclass)

# %%
for t in range (0,1000,100):
    t = t/100000
    print(t)
    run_kncs_report(white_norm_input.values,white_targetclass,t)

# %%
def run_knnw_report(inputs, targets):
    print("_______________________________________________________________________________________________")
    print("KNN with inverse distance as weight:")
    for n_neighbour in range(1,21):
        print(str(n_neighbour) + " neighbours:")
        knn_estimator = KNeighborsClassifier(n_neighbour,weights='distance')
        print(str(n_neighbour)+ " neighbours//")
        predicted = cross_val_predict(knn_estimator,inputs,targets,cv=cv)
        print(confusion_matrix_report(targets,predicted))
        print(classification_report(targets,predicted))
        try:
            print("RMSE:")
            print(root_mean_squared_error(targets,predicted))
        except(Error e):
            pass

# %%
run_knnw_report(white_norm_input.values,white_targetclass)

# %%
run_knnw_report(red_norm_input.values,red_targetclass)

# %%
run_knnw_report(log_white_norm.values,white_targetclass)

# %%
run_knnw_report(log_red_norm.values,red_targetclass)

# %%
run_knnw_report(mm_white_norm.values,white_targetclass)

# %%
run_knnw_report(mm_red_norm.values,red_targetclass)

# %%
run_knn_report(white_norm_filtered.values,white_targetclass)

# %%
run_knnw_report(white_norm_filtered.values,white_targetclass)

# %%
run_knn_report(red_norm_filtered.values,red_targetclass)
run_knnw_report(red_norm_filtered.values,red_targetclass)

# %%
run_knn_report(f_log_red.values,red_targetclass)
run_knnw_report(f_log_red.values,red_targetclass)

# %%
run_knn_report(f_log_white.values,white_targetclass)
run_knnw_report(f_log_white.values,white_targetclass)

# %%
run_knn_report(f_mm_red.values,red_targetclass)
run_knnw_report(f_mm_red.values,red_targetclass)

# %%
run_knn_report(f_mm_white.values,white_targetclass)
run_knnw_report(f_mm_white.values,white_targetclass)
