# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from copy import deepcopy
from scipy.stats import iqr

# %%
red = pd.read_csv("./data/winequality-red1.csv")
#red.head()

# %%
red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Korrelationen

# %%
redcopy = deepcopy(red)
redcopy.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %% [markdown]
# ### Multiplikationen

# %%
redcopy["free x total sulfur dioxide"] = redcopy["free sulfur dioxide"] * redcopy["total sulfur dioxide"]
redcopy["fixed acidity x citric acid"] = redcopy["fixed acidity"] * redcopy["citric acid"]
redcopy["fixed acidity x density"] = redcopy["fixed acidity"] * redcopy["density"]
redcopy["fixed acidity x pH"] = redcopy["fixed acidity"] * redcopy["pH"]
redcopy["volatile acidity x citric acid"] = redcopy["volatile acidity"] * redcopy["citric acid"]
redcopy["citric acid x pH"] = redcopy["citric acid"] * redcopy["pH"]
redcopy["alcohol x density"] = redcopy["alcohol"] * redcopy["density"]
redcopy["fixed acidity x residual sugar"] = redcopy["fixed acidity"] * redcopy["residual sugar"]


redcopy.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  free x total sulfur dioxide  fixed acidity x citric acid  \
# 0      9.4        5                        374.0                        0.000
# 1      9.8        5                       1675.0                        0.000
# 2      9.8        5                        810.0                        0.312
# 3      9.8        6                       1020.0                        6.272
# 4      9.4        5                        374.0                        0.000
#
#    fixed acidity x density  fixed acidity x pH  \
# 0                  7.38372              25.974
# 1                  7.77504              24.960
# 2                  7.77660              25.428
# 3                 11.17760              35.392
# 4                  7.38372              25.974
#
#    volatile acidity x citric acid  citric acid x pH  alcohol x density  \
# 0                          0.0000            0.0000            9.37932
# 1                          0.0000            0.0000            9.76864
# 2                          0.0304            0.1304            9.77060
# 3                          0.1568            1.7696            9.78040
# 4                          0.0000            0.0000            9.37932
#
#    fixed acidity x residual sugar
# 0                           14.06
# 1                           20.28
# 2                           17.94
# 3                           21.28
# 4                           14.06

# %% [markdown]
# ### Potenzen

# %%
redcopy["free sulfur dioxide^2"] = redcopy["free sulfur dioxide"] * redcopy["free sulfur dioxide"]
redcopy["total sulfur dioxide^2"] = redcopy["total sulfur dioxide"] * redcopy["total sulfur dioxide"]
redcopy["fixed acidity^2"] = redcopy["fixed acidity"] * redcopy["fixed acidity"]
redcopy["citric acid^2"] = redcopy["citric acid"] * redcopy["citric acid"]
redcopy["density^2"] = redcopy["density"] * redcopy["density"]
redcopy["pH^2"] = redcopy["pH"] * redcopy["pH"]
redcopy["volatile acidity^2"] = redcopy["volatile acidity"] * redcopy["volatile acidity"]
redcopy["alcohol^2"] = redcopy["alcohol"] * redcopy["alcohol"]
redcopy["residual sugar^2"] = redcopy["residual sugar"] * redcopy["residual sugar"]


redcopy.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#          ...         fixed acidity x residual sugar  free sulfur dioxide^2  \
# 0        ...                                  14.06                  121.0
# 1        ...                                  20.28                  625.0
# 2        ...                                  17.94                  225.0
# 3        ...                                  21.28                  289.0
# 4        ...                                  14.06                  121.0
#
#    total sulfur dioxide^2  fixed acidity^2  citric acid^2  density^2     pH^2  \
# 0                  1156.0            54.76         0.0000   0.995605  12.3201
# 1                  4489.0            60.84         0.0000   0.993610  10.2400
# 2                  2916.0            60.84         0.0016   0.994009  10.6276
# 3                  3600.0           125.44         0.3136   0.996004   9.9856
# 4                  1156.0            54.76         0.0000   0.995605  12.3201
#
#    volatile acidity^2  alcohol^2  residual sugar^2
# 0              0.4900      88.36              3.61
# 1              0.7744      96.04              6.76
# 2              0.5776      96.04              5.29
# 3              0.0784      96.04              3.61
# 4              0.4900      88.36              3.61
#
# [5 rows x 29 columns]

# %%
redcopy.corr()
# Out:
#                                 fixed acidity  volatile acidity  citric acid  \
# fixed acidity                        1.000000         -0.256131     0.671703
# volatile acidity                    -0.256131          1.000000    -0.552496
# citric acid                          0.671703         -0.552496     1.000000
# residual sugar                       0.114777          0.001918     0.143577
# chlorides                            0.093705          0.061298     0.203823
# free sulfur dioxide                 -0.153794         -0.010504    -0.060978
# total sulfur dioxide                -0.113181          0.076470     0.035533
# density                              0.668047          0.022026     0.364947
# pH                                  -0.682978          0.234937    -0.541904
# sulphates                            0.183006         -0.260987     0.312770
# alcohol                             -0.061668         -0.202288     0.109903
# quality                              0.124052         -0.390558     0.226373
# free x total sulfur dioxide         -0.107816          0.016766     0.026716
# fixed acidity x citric acid          0.826106         -0.487782     0.956682
# fixed acidity x density              0.999976         -0.254288     0.670854
# fixed acidity x pH                   0.983025         -0.240396     0.641474
# volatile acidity x citric acid       0.601358         -0.125129     0.846067
# citric acid x pH                     0.643001         -0.562350     0.997257
# alcohol x density                   -0.049216         -0.203652     0.118041
# fixed acidity x residual sugar       0.452050         -0.078096     0.348343
# free sulfur dioxide^2               -0.114568         -0.022074    -0.038300
# total sulfur dioxide^2              -0.086749          0.053345     0.069310
# fixed acidity^2                      0.990417         -0.251180     0.659421
# citric acid^2                        0.664465         -0.468623     0.946907
# density^2                            0.668288          0.021908     0.365134
# pH^2                                -0.679656          0.236757    -0.538816
# volatile acidity^2                  -0.224831          0.969388    -0.493442
# alcohol^2                           -0.065424         -0.202158     0.109805
# residual sugar^2                     0.059598         -0.021618     0.104110
#
#                                 residual sugar  chlorides  \
# fixed acidity                         0.114777   0.093705
# volatile acidity                      0.001918   0.061298
# citric acid                           0.143577   0.203823
# residual sugar                        1.000000   0.055610
# chlorides                             0.055610   1.000000
# free sulfur dioxide                   0.187049   0.005562
# total sulfur dioxide                  0.203028   0.047400
# density                               0.355283   0.200632
# pH                                   -0.085652  -0.265026
# sulphates                             0.005527   0.371260
# alcohol                               0.042075  -0.221141
# quality                               0.013732  -0.128907
# free x total sulfur dioxide           0.277960   0.032428
# fixed acidity x citric acid           0.141072   0.169165
# fixed acidity x density               0.117444   0.094709
# fixed acidity x pH                    0.111939   0.046570
# volatile acidity x citric acid        0.160172   0.274410
# citric acid x pH                      0.142789   0.183471
# alcohol x density                     0.049062  -0.219363
# fixed acidity x residual sugar        0.915461   0.086433
# free sulfur dioxide^2                 0.260991   0.025121
# total sulfur dioxide^2                0.228816   0.020133
# fixed acidity^2                       0.118612   0.075877
# citric acid^2                         0.149985   0.254741
# density^2                             0.355689   0.200523
# pH^2                                 -0.087369  -0.259485
# volatile acidity^2                   -0.004455   0.048722
# alcohol^2                             0.044808  -0.215949
# residual sugar^2                      0.932447   0.066529
#
#                                 free sulfur dioxide  total sulfur dioxide  \
# fixed acidity                             -0.153794             -0.113181
# volatile acidity                          -0.010504              0.076470
# citric acid                               -0.060978              0.035533
# residual sugar                             0.187049              0.203028
# chlorides                                  0.005562              0.047400
# free sulfur dioxide                        1.000000              0.667666
# total sulfur dioxide                       0.667666              1.000000
# density                                   -0.021946              0.071269
# pH                                         0.070377             -0.066495
# sulphates                                  0.051658              0.042947
# alcohol                                   -0.069408             -0.205654
# quality                                   -0.050656             -0.185100
# free x total sulfur dioxide                0.856337              0.868568
# fixed acidity x citric acid               -0.104562             -0.035570
# fixed acidity x density                   -0.153008             -0.111835
# fixed acidity x pH                        -0.155977             -0.142308
# volatile acidity x citric acid            -0.031716              0.156531
# citric acid x pH                          -0.054528              0.038073
# alcohol x density                         -0.070707             -0.206533
# fixed acidity x residual sugar             0.104951              0.124683
# free sulfur dioxide^2                      0.939255              0.574853
# total sulfur dioxide^2                     0.527010              0.918286
# fixed acidity^2                           -0.153192             -0.119416
# citric acid^2                             -0.085353             -0.022639
# density^2                                 -0.021817              0.071372
# pH^2                                       0.069658             -0.065065
# volatile acidity^2                        -0.022607              0.053507
# alcohol^2                                 -0.067689             -0.196408
# residual sugar^2                           0.199179              0.178774
#
#                                  density        pH  sulphates  \
# fixed acidity                   0.668047 -0.682978   0.183006
# volatile acidity                0.022026  0.234937  -0.260987
# citric acid                     0.364947 -0.541904   0.312770
# residual sugar                  0.355283 -0.085652   0.005527
# chlorides                       0.200632 -0.265026   0.371260
# free sulfur dioxide            -0.021946  0.070377   0.051658
# total sulfur dioxide            0.071269 -0.066495   0.042947
# density                         1.000000 -0.341699   0.148506
# pH                             -0.341699  1.000000  -0.196648
# sulphates                       0.148506 -0.196648   1.000000
# alcohol                        -0.496180  0.205633   0.093595
# quality                        -0.174919 -0.057731   0.251397
# free x total sulfur dioxide     0.037903 -0.042354   0.027154
# fixed acidity x citric acid     0.476675 -0.595106   0.291569
# fixed acidity x density         0.672885 -0.681542   0.183198
# fixed acidity x pH              0.692059 -0.545818   0.159721
# volatile acidity x citric acid  0.431310 -0.518415   0.225247
# citric acid x pH                0.352495 -0.495928   0.302782
# alcohol x density              -0.481443  0.200812   0.097299
# fixed acidity x residual sugar  0.548787 -0.299383   0.077023
# free sulfur dioxide^2           0.008155  0.041306   0.037428
# total sulfur dioxide^2          0.025346 -0.107194   0.019237
# fixed acidity^2                 0.651662 -0.650003   0.180537
# citric acid^2                   0.366629 -0.503729   0.314741
# density^2                       0.999999 -0.341726   0.148537
# pH^2                           -0.342166  0.999257  -0.188343
# volatile acidity^2             -0.000287  0.227913  -0.248202
# alcohol^2                      -0.499882  0.204721   0.093237
# residual sugar^2                0.276593 -0.070824   0.002040
#
#                                       ...         \
# fixed acidity                         ...
# volatile acidity                      ...
# citric acid                           ...
# residual sugar                        ...
# chlorides                             ...
# free sulfur dioxide                   ...
# total sulfur dioxide                  ...
# density                               ...
# pH                                    ...
# sulphates                             ...
# alcohol                               ...
# quality                               ...
# free x total sulfur dioxide           ...
# fixed acidity x citric acid           ...
# fixed acidity x density               ...
# fixed acidity x pH                    ...
# volatile acidity x citric acid        ...
# citric acid x pH                      ...
# alcohol x density                     ...
# fixed acidity x residual sugar        ...
# free sulfur dioxide^2                 ...
# total sulfur dioxide^2                ...
# fixed acidity^2                       ...
# citric acid^2                         ...
# density^2                             ...
# pH^2                                  ...
# volatile acidity^2                    ...
# alcohol^2                             ...
# residual sugar^2                      ...
#
#                                 fixed acidity x residual sugar  \
# fixed acidity                                         0.452050
# volatile acidity                                     -0.078096
# citric acid                                           0.348343
# residual sugar                                        0.915461
# chlorides                                             0.086433
# free sulfur dioxide                                   0.104951
# total sulfur dioxide                                  0.124683
# density                                               0.548787
# pH                                                   -0.299383
# sulphates                                             0.077023
# alcohol                                               0.032526
# quality                                               0.060909
# free x total sulfur dioxide                           0.187599
# fixed acidity x citric acid                           0.410494
# fixed acidity x density                               0.454571
# fixed acidity x pH                                    0.445215
# volatile acidity x citric acid                        0.347959
# citric acid x pH                                      0.336821
# alcohol x density                                     0.043235
# fixed acidity x residual sugar                        1.000000
# free sulfur dioxide^2                                 0.177652
# total sulfur dioxide^2                                0.150061
# fixed acidity^2                                       0.457998
# citric acid^2                                         0.356879
# density^2                                             0.549342
# pH^2                                                 -0.298889
# volatile acidity^2                                   -0.075588
# alcohol^2                                             0.036112
# residual sugar^2                                      0.848706
#
#                                 free sulfur dioxide^2  total sulfur dioxide^2  \
# fixed acidity                               -0.114568               -0.086749
# volatile acidity                            -0.022074                0.053345
# citric acid                                 -0.038300                0.069310
# residual sugar                               0.260991                0.228816
# chlorides                                    0.025121                0.020133
# free sulfur dioxide                          0.939255                0.527010
# total sulfur dioxide                         0.574853                0.918286
# density                                      0.008155                0.025346
# pH                                           0.041306               -0.107194
# sulphates                                    0.037428                0.019237
# alcohol                                     -0.058415               -0.140444
# quality                                     -0.043511               -0.142416
# free x total sulfur dioxide                  0.859766                0.843652
# fixed acidity x citric acid                 -0.072200               -0.000337
# fixed acidity x density                     -0.113775               -0.086021
# fixed acidity x pH                          -0.117702               -0.121790
# volatile acidity x citric acid              -0.027229                0.155132
# citric acid x pH                            -0.033951                0.067320
# alcohol x density                           -0.059025               -0.141577
# fixed acidity x residual sugar               0.177652                0.150061
# free sulfur dioxide^2                        1.000000                0.485298
# total sulfur dioxide^2                       0.485298                1.000000
# fixed acidity^2                             -0.114678               -0.094793
# citric acid^2                               -0.056425                0.028370
# density^2                                    0.008317                0.025460
# pH^2                                         0.040583               -0.105471
# volatile acidity^2                          -0.025346                0.043090
# alcohol^2                                   -0.057138               -0.132841
# residual sugar^2                             0.284731                0.201401
#
#                                 fixed acidity^2  citric acid^2  density^2  \
# fixed acidity                          0.990417       0.664465   0.668288
# volatile acidity                      -0.251180      -0.468623   0.021908
# citric acid                            0.659421       0.946907   0.365134
# residual sugar                         0.118612       0.149985   0.355689
# chlorides                              0.075877       0.254741   0.200523
# free sulfur dioxide                   -0.153192      -0.085353  -0.021817
# total sulfur dioxide                  -0.119416      -0.022639   0.071372
# density                                0.651662       0.366629   0.999999
# pH                                    -0.650003      -0.503729  -0.341726
# sulphates                              0.180537       0.314741   0.148537
# alcohol                               -0.029817       0.138345  -0.495623
# quality                                0.128116       0.216432  -0.174664
# free x total sulfur dioxide           -0.113225      -0.011594   0.038066
# fixed acidity x citric acid            0.829451       0.945066   0.476969
# fixed acidity x density                0.990578       0.663859   0.673128
# fixed acidity x pH                     0.972984       0.636453   0.692293
# volatile acidity x citric acid         0.590404       0.789618   0.431494
# citric acid x pH                       0.629197       0.934833   0.352667
# alcohol x density                     -0.017409       0.146819  -0.480883
# fixed acidity x residual sugar         0.457998       0.356879   0.549342
# free sulfur dioxide^2                 -0.114678      -0.056425   0.008317
# total sulfur dioxide^2                -0.094793       0.028370   0.025460
# fixed acidity^2                        1.000000       0.666045   0.652005
# citric acid^2                          0.666045       1.000000   0.366869
# density^2                              0.652005       0.366869   1.000000
# pH^2                                  -0.644412      -0.497644  -0.342176
# volatile acidity^2                    -0.221536      -0.414765  -0.000390
# alcohol^2                             -0.032340       0.138720  -0.499299
# residual sugar^2                       0.062996       0.105260   0.277056
#
#                                     pH^2  volatile acidity^2  alcohol^2  \
# fixed acidity                  -0.679656           -0.224831  -0.065424
# volatile acidity                0.236757            0.969388  -0.202158
# citric acid                    -0.538816           -0.493442   0.109805
# residual sugar                 -0.087369           -0.004455   0.044808
# chlorides                      -0.259485            0.048722  -0.215949
# free sulfur dioxide             0.069658           -0.022607  -0.067689
# total sulfur dioxide           -0.065065            0.053507  -0.196408
# density                        -0.342166           -0.000287  -0.499882
# pH                              0.999257            0.227913   0.204721
# sulphates                      -0.188343           -0.248202   0.093237
# alcohol                         0.209947           -0.160414   0.998260
# quality                        -0.057688           -0.368028   0.473278
# free x total sulfur dioxide    -0.041976            0.010186  -0.126085
# fixed acidity x citric acid    -0.589496           -0.436274   0.098187
# fixed acidity x density        -0.678212           -0.223407  -0.068861
# fixed acidity x pH             -0.544067           -0.205243  -0.038465
# volatile acidity x citric acid -0.514149           -0.120609  -0.019164
# citric acid x pH               -0.494064           -0.501580   0.119529
# alcohol x density               0.205138           -0.161812   0.997954
# fixed acidity x residual sugar -0.298889           -0.075588   0.036112
# free sulfur dioxide^2           0.040583           -0.025346  -0.057138
# total sulfur dioxide^2         -0.105471            0.043090  -0.132841
# fixed acidity^2                -0.644412           -0.221536  -0.032340
# citric acid^2                  -0.497644           -0.414765   0.138720
# density^2                      -0.342176           -0.000390  -0.499299
# pH^2                            1.000000            0.229873   0.209414
# volatile acidity^2              0.229873            1.000000  -0.161591
# alcohol^2                       0.209414           -0.161591   1.000000
# residual sugar^2               -0.071726           -0.023409  -0.004574
#
#                                 residual sugar^2
# fixed acidity                           0.059598
# volatile acidity                       -0.021618
# citric acid                             0.104110
# residual sugar                          0.932447
# chlorides                               0.066529
# free sulfur dioxide                     0.199179
# total sulfur dioxide                    0.178774
# density                                 0.276593
# pH                                     -0.070824
# sulphates                               0.002040
# alcohol                                -0.008783
# quality                                 0.003259
# free x total sulfur dioxide             0.271414
# fixed acidity x citric acid             0.090985
# fixed acidity x density                 0.061912
# fixed acidity x pH                      0.051010
# volatile acidity x citric acid          0.105054
# citric acid x pH                        0.103325
# alcohol x density                      -0.003946
# fixed acidity x residual sugar          0.848706
# free sulfur dioxide^2                   0.284731
# total sulfur dioxide^2                  0.201401
# fixed acidity^2                         0.062996
# citric acid^2                           0.105260
# density^2                               0.277056
# pH^2                                   -0.071726
# volatile acidity^2                     -0.023409
# alcohol^2                              -0.004574
# residual sugar^2                        1.000000
#
# [29 rows x 29 columns]

# %% [markdown]
# ## Abstände vom Mittelwert

# %%
red_mean = deepcopy(red)

# %%
red_mean.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
red_mean["fixed acidity mean"] =  abs(red_mean["fixed acidity"] - red_mean["fixed acidity"].mean())
red_mean["volatile acidity mean"] =  abs(red_mean["volatile acidity"] - red_mean["volatile acidity"].mean())
red_mean["citric acid mean"] =  abs(red_mean["citric acid"] - red_mean["citric acid"].mean())
red_mean["residual sugar mean"] =  abs(red_mean["residual sugar"] - red_mean["residual sugar"].mean())
red_mean["chlorides mean"] =  abs(red_mean["chlorides"] - red_mean["chlorides"].mean())
red_mean["free sulfur dioxide mean"] =  abs(red_mean["free sulfur dioxide"] - red_mean["free sulfur dioxide"].mean())
red_mean["total sulfur dioxide mean"] =  abs(red_mean["total sulfur dioxide"] - red_mean["total sulfur dioxide"].mean())
red_mean["density mean"] =  abs(red_mean["density"] - red_mean["density"].mean())
red_mean["pH mean"] =  abs(red_mean["pH"] - red_mean["pH"].mean())
red_mean["sulphates mean"] =  abs(red_mean["sulphates"] - red_mean["sulphates"].mean())
red_mean["alcohol mean"] =  abs(red_mean["alcohol"] - red_mean["alcohol"].mean())

# %%
red_mean.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#        ...       volatile acidity mean  citric acid mean  residual sugar mean  \
# 0      ...                    0.172179          0.270976             0.638806
# 1      ...                    0.352179          0.270976             0.061194
# 2      ...                    0.232179          0.230976             0.238806
# 3      ...                    0.247821          0.289024             0.638806
# 4      ...                    0.172179          0.270976             0.638806
#
#    chlorides mean  free sulfur dioxide mean  total sulfur dioxide mean  \
# 0        0.011467                  4.874922                  12.467792
# 1        0.010533                  9.125078                  20.532208
# 2        0.004533                  0.874922                   7.532208
# 3        0.012467                  1.125078                  13.532208
# 4        0.011467                  4.874922                  12.467792
#
#    density mean   pH mean  sulphates mean  alcohol mean
# 0      0.001053  0.198887        0.098149      1.022983
# 1      0.000053  0.111113        0.021851      0.622983
# 2      0.000253  0.051113        0.008149      0.622983
# 3      0.001253  0.151113        0.078149      0.622983
# 4      0.001053  0.198887        0.098149      1.022983
#
# [5 rows x 23 columns]

# %%
red_mean.corr()
# Out:
#                            fixed acidity  volatile acidity  citric acid  \
# fixed acidity                   1.000000         -0.256131     0.671703
# volatile acidity               -0.256131          1.000000    -0.552496
# citric acid                     0.671703         -0.552496     1.000000
# residual sugar                  0.114777          0.001918     0.143577
# chlorides                       0.093705          0.061298     0.203823
# free sulfur dioxide            -0.153794         -0.010504    -0.060978
# total sulfur dioxide           -0.113181          0.076470     0.035533
# density                         0.668047          0.022026     0.364947
# pH                             -0.682978          0.234937    -0.541904
# sulphates                       0.183006         -0.260987     0.312770
# alcohol                        -0.061668         -0.202288     0.109903
# quality                         0.124052         -0.390558     0.226373
# fixed acidity mean              0.450570         -0.131497     0.293113
# volatile acidity mean           0.035683          0.237773     0.033911
# citric acid mean                0.237529          0.029609     0.171620
# residual sugar mean            -0.000956         -0.015193     0.070470
# chlorides mean                 -0.031758         -0.009424     0.176406
# free sulfur dioxide mean        0.039287         -0.059940     0.066390
# total sulfur dioxide mean      -0.039219          0.054552     0.087576
# density mean                    0.192642         -0.092200     0.144535
# pH mean                         0.047184          0.084831     0.027243
# sulphates mean                  0.035725         -0.022909     0.113900
# alcohol mean                   -0.088682         -0.102361     0.076279
#
#                            residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity                    0.114777   0.093705            -0.153794
# volatile acidity                 0.001918   0.061298            -0.010504
# citric acid                      0.143577   0.203823            -0.060978
# residual sugar                   1.000000   0.055610             0.187049
# chlorides                        0.055610   1.000000             0.005562
# free sulfur dioxide              0.187049   0.005562             1.000000
# total sulfur dioxide             0.203028   0.047400             0.667666
# density                          0.355283   0.200632            -0.021946
# pH                              -0.085652  -0.265026             0.070377
# sulphates                        0.005527   0.371260             0.051658
# alcohol                          0.042075  -0.221141            -0.069408
# quality                          0.013732  -0.128907            -0.050656
# fixed acidity mean               0.096230  -0.081955            -0.075121
# volatile acidity mean           -0.014526  -0.035667            -0.046137
# citric acid mean                 0.046203   0.159333            -0.124593
# residual sugar mean              0.871903   0.059166             0.177384
# chlorides mean                   0.005923   0.872814             0.006573
# free sulfur dioxide mean         0.249006   0.013908             0.530355
# total sulfur dioxide mean        0.199270  -0.006819             0.180931
# density mean                     0.219844  -0.091321             0.055788
# pH mean                         -0.037427   0.117198            -0.006583
# sulphates mean                  -0.026088   0.388037             0.052835
# alcohol mean                     0.056115  -0.019155            -0.022063
#
#                            total sulfur dioxide   density        pH  \
# fixed acidity                         -0.113181  0.668047 -0.682978
# volatile acidity                       0.076470  0.022026  0.234937
# citric acid                            0.035533  0.364947 -0.541904
# residual sugar                         0.203028  0.355283 -0.085652
# chlorides                              0.047400  0.200632 -0.265026
# free sulfur dioxide                    0.667666 -0.021946  0.070377
# total sulfur dioxide                   1.000000  0.071269 -0.066495
# density                                0.071269  1.000000 -0.341699
# pH                                    -0.066495 -0.341699  1.000000
# sulphates                              0.042947  0.148506 -0.196648
# alcohol                               -0.205654 -0.496180  0.205633
# quality                               -0.185100 -0.174919 -0.057731
# fixed acidity mean                    -0.135772  0.235677 -0.109521
# volatile acidity mean                 -0.066510 -0.072755  0.051705
# citric acid mean                      -0.232999  0.119299 -0.049448
# residual sugar mean                    0.157340  0.181313 -0.058419
# chlorides mean                         0.003517 -0.042288 -0.175505
# free sulfur dioxide mean               0.221901  0.055344 -0.063232
# total sulfur dioxide mean              0.602031 -0.014426 -0.140805
# density mean                           0.015295  0.030530 -0.009336
# pH mean                                0.012812 -0.003068  0.060254
# sulphates mean                         0.121176  0.005460 -0.258029
# alcohol mean                           0.023297 -0.311966  0.065174
#
#                            sulphates      ...       volatile acidity mean  \
# fixed acidity               0.183006      ...                    0.035683
# volatile acidity           -0.260987      ...                    0.237773
# citric acid                 0.312770      ...                    0.033911
# residual sugar              0.005527      ...                   -0.014526
# chlorides                   0.371260      ...                   -0.035667
# free sulfur dioxide         0.051658      ...                   -0.046137
# total sulfur dioxide        0.042947      ...                   -0.066510
# density                     0.148506      ...                   -0.072755
# pH                         -0.196648      ...                    0.051705
# sulphates                   1.000000      ...                   -0.038837
# alcohol                     0.093595      ...                    0.093689
# quality                     0.251397      ...                   -0.029492
# fixed acidity mean          0.077776      ...                   -0.034984
# volatile acidity mean      -0.038837      ...                    1.000000
# citric acid mean            0.093545      ...                    0.091466
# residual sugar mean         0.006273      ...                    0.005788
# chlorides mean              0.404169      ...                    0.008746
# free sulfur dioxide mean    0.006266      ...                    0.056616
# total sulfur dioxide mean  -0.024902      ...                    0.042033
# density mean                0.021115      ...                    0.004833
# pH mean                     0.181373      ...                    0.037038
# sulphates mean              0.622959      ...                    0.069097
# alcohol mean                0.025422      ...                   -0.005528
#
#                            citric acid mean  residual sugar mean  \
# fixed acidity                      0.237529            -0.000956
# volatile acidity                   0.029609            -0.015193
# citric acid                        0.171620             0.070470
# residual sugar                     0.046203             0.871903
# chlorides                          0.159333             0.059166
# free sulfur dioxide               -0.124593             0.177384
# total sulfur dioxide              -0.232999             0.157340
# density                            0.119299             0.181313
# pH                                -0.049448            -0.058419
# sulphates                          0.093545             0.006273
# alcohol                            0.154295            -0.007705
# quality                            0.077075            -0.007284
# fixed acidity mean                 0.394065             0.069000
# volatile acidity mean              0.091466             0.005788
# citric acid mean                   1.000000             0.026455
# residual sugar mean                0.026455             1.000000
# chlorides mean                     0.163448             0.078113
# free sulfur dioxide mean           0.007338             0.272165
# total sulfur dioxide mean         -0.078331             0.196872
# density mean                       0.174692             0.201592
# pH mean                            0.251611             0.001067
# sulphates mean                     0.034460             0.017473
# alcohol mean                       0.068997             0.064405
#
#                            chlorides mean  free sulfur dioxide mean  \
# fixed acidity                   -0.031758                  0.039287
# volatile acidity                -0.009424                 -0.059940
# citric acid                      0.176406                  0.066390
# residual sugar                   0.005923                  0.249006
# chlorides                        0.872814                  0.013908
# free sulfur dioxide              0.006573                  0.530355
# total sulfur dioxide             0.003517                  0.221901
# density                         -0.042288                  0.055344
# pH                              -0.175505                 -0.063232
# sulphates                        0.404169                  0.006266
# alcohol                         -0.047630                 -0.002708
# quality                         -0.035405                 -0.021390
# fixed acidity mean              -0.050151                 -0.005542
# volatile acidity mean            0.008746                  0.056616
# citric acid mean                 0.163448                  0.007338
# residual sugar mean              0.078113                  0.272165
# chlorides mean                   1.000000                  0.032857
# free sulfur dioxide mean         0.032857                  1.000000
# total sulfur dioxide mean       -0.002222                  0.324034
# density mean                     0.019785                  0.079780
# pH mean                          0.176991                 -0.021490
# sulphates mean                   0.426873                  0.056540
# alcohol mean                     0.107886                 -0.004753
#
#                            total sulfur dioxide mean  density mean   pH mean  \
# fixed acidity                              -0.039219      0.192642  0.047184
# volatile acidity                            0.054552     -0.092200  0.084831
# citric acid                                 0.087576      0.144535  0.027243
# residual sugar                              0.199270      0.219844 -0.037427
# chlorides                                  -0.006819     -0.091321  0.117198
# free sulfur dioxide                         0.180931      0.055788 -0.006583
# total sulfur dioxide                        0.602031      0.015295  0.012812
# density                                    -0.014426      0.030530 -0.003068
# pH                                         -0.140805     -0.009336  0.060254
# sulphates                                  -0.024902      0.021115  0.181373
# alcohol                                    -0.067250      0.363647  0.105380
# quality                                    -0.118808      0.173072 -0.011425
# fixed acidity mean                         -0.106345      0.477069  0.438121
# volatile acidity mean                       0.042033      0.004833  0.037038
# citric acid mean                           -0.078331      0.174692  0.251611
# residual sugar mean                         0.196872      0.201592  0.001067
# chlorides mean                             -0.002222      0.019785  0.176991
# free sulfur dioxide mean                    0.324034      0.079780 -0.021490
# total sulfur dioxide mean                   1.000000      0.022544 -0.011372
# density mean                                0.022544      1.000000  0.224922
# pH mean                                    -0.011372      0.224922  1.000000
# sulphates mean                              0.105895     -0.024249  0.142985
# alcohol mean                                0.076367      0.346260  0.146591
#
#                            sulphates mean  alcohol mean
# fixed acidity                    0.035725     -0.088682
# volatile acidity                -0.022909     -0.102361
# citric acid                      0.113900      0.076279
# residual sugar                  -0.026088      0.056115
# chlorides                        0.388037     -0.019155
# free sulfur dioxide              0.052835     -0.022063
# total sulfur dioxide             0.121176      0.023297
# density                          0.005460     -0.311966
# pH                              -0.258029      0.065174
# sulphates                        0.622959      0.025422
# alcohol                         -0.083477      0.459139
# quality                         -0.051196      0.208796
# fixed acidity mean              -0.066192      0.066495
# volatile acidity mean            0.069097     -0.005528
# citric acid mean                 0.034460      0.068997
# residual sugar mean              0.017473      0.064405
# chlorides mean                   0.426873      0.107886
# free sulfur dioxide mean         0.056540     -0.004753
# total sulfur dioxide mean        0.105895      0.076367
# density mean                    -0.024249      0.346260
# pH mean                          0.142985      0.146591
# sulphates mean                   1.000000      0.015380
# alcohol mean                     0.015380      1.000000
#
# [23 rows x 23 columns]

# %%
red_mean[red_mean["quality"]==8].mean()
# Out:
# fixed acidity                 8.566667
# volatile acidity              0.423333
# citric acid                   0.391111
# residual sugar                2.577778
# chlorides                     0.068444
# free sulfur dioxide          13.277778
# total sulfur dioxide         33.444444
# density                       0.995212
# pH                            3.267222
# sulphates                     0.767778
# alcohol                      12.094444
# quality                       8.000000
# fixed acidity mean            1.733333
# volatile acidity mean         0.156567
# citric acid mean              0.195014
# residual sugar mean           0.846269
# chlorides mean                0.019022
# free sulfur dioxide mean      9.333299
# total sulfur dioxide mean    25.593218
# density mean                  0.002237
# pH mean                       0.163149
# sulphates mean                0.114567
# alcohol mean                  1.787680
# dtype: float64

# %% [markdown]
# ## Binning

# %%
red_binned = deepcopy(red)

# %%
red_binned["fixed acidity"].quantile(0.25)-1.5*iqr(red_binned["fixed acidity"])
# Out:
# 3.95

# %%
fixed_acidity = []

for i in red_binned["fixed acidity"]:
    if i < red_binned["fixed acidity"].quantile(0.25)-1.5*iqr(red_binned["fixed acidity"]):
        i = 0
    else:
        if i > red_binned["fixed acidity"].quantile(0.75)+1.5*iqr(red_binned["fixed acidity"]):
                i = 0
        else: i = 1

                
    fixed_acidity.append(i)
    
fa = pd.DataFrame(fixed_acidity)

# %%
red_binned["fixed acidity edited"] = fa
red_binned.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  fixed acidity edited
# 0      9.4        5                     1
# 1      9.8        5                     1
# 2      9.8        5                     1
# 3      9.8        6                     1
# 4      9.4        5                     1

# %%
pd.crosstab(red_binned["fixed acidity edited"], red_binned["quality"])
# Out:
# quality                3   4    5    6    7   8
# fixed acidity edited
# 0                      0   1   15   22   10   1
# 1                     10  52  666  616  189  17

# %%
sulfur_dioxide = []

for i in red_binned["total sulfur dioxide"]:
    if i > red_binned["total sulfur dioxide"].quantile(0.95):
        i = 0
    else:
        i = 1

                
    sulfur_dioxide.append(i)
    
fa = pd.DataFrame(sulfur_dioxide)

# %%
red_binned["sulfur dioxide edited"] = ca
red_binned.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-afcc94970bb7> in <module>()
# ----> 1 red_binned["sulfur dioxide edited"] = ca
#       2 red_binned.head()
#
# NameError: name 'ca' is not defined

# %%
pd.crosstab(red_binned["sulfur dioxide edited"], red_binned["quality"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sulfur dioxide edited'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-7e067c82d892> in <module>()
# ----> 1 pd.crosstab(red_binned["sulfur dioxide edited"], red_binned["quality"])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#    3067         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sulfur dioxide edited'

# %%
red_binned.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality  \
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000
#
#        fixed acidity edited
# count           1599.000000
# mean               0.969356
# std                0.172406
# min                0.000000
# 25%                1.000000
# 50%                1.000000
# 75%                1.000000
# max                1.000000

# %%
red_binned["total sulfur dioxide"].quantile(0.95)
# Out:
# 112.09999999999991

# %%
red_binned[red_binned["fixed acidity"]>=red_binned["fixed acidity"].quantile(0.75)+1.5*iqr(red_binned["fixed acidity"])].count()
# Out:
# fixed acidity           49
# volatile acidity        49
# citric acid             49
# residual sugar          49
# chlorides               49
# free sulfur dioxide     49
# total sulfur dioxide    49
# density                 49
# pH                      49
# sulphates               49
# alcohol                 49
# quality                 49
# fixed acidity edited    49
# dtype: int64

# %% [markdown]
# ### Choosing data

# %%
data_normal = deepcopy(red)
label_normal = data_normal.pop("quality")

# %%
label_normal.head()
# Out:
# 0    5
# 1    5
# 2    5
# 3    6
# 4    5
# Name: quality, dtype: int64

# %%
data_multiplied = deepcopy(redcopy)
label_multiplied = data_multiplied.pop("quality")

# %%
data_mean = deepcopy(red_mean)
label_mean = data_mean.pop("quality")

# %%
data_class = deepcopy(red)

conditions = [(data_class['quality'] <= 4),
              (data_class['quality'] >= 8)]
choices = ['1 - low', '3 - high']
data_class['quality class'] = np.select(conditions, choices, default = '2 - middle')


label_class = data_class.pop("quality")
label_class = data_class.pop("quality class")

# %%
label_class.head()
# Out:
# 0    2 - middle
# 1    2 - middle
# 2    2 - middle
# 3    2 - middle
# 4    2 - middle
# Name: quality class, dtype: object

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.model_selection import train_test_split  
train_data, test_data, train_label, test_label = train_test_split(data_normal, label_normal, test_size=0.20)

# %%
from sklearn.naive_bayes import GaussianNB

model = GaussianNB().fit(train_data, train_label)

# %%
prediction_test = model.predict(test_data)

print(np.mean(prediction_test == test_label))
# Out:
# 0.534375

# %%
from sklearn.metrics import classification_report, confusion_matrix  
print(confusion_matrix(test_label, prediction_test))  
print(classification_report(test_label, prediction_test))
# Out:
# [[ 1  0  1  0  0  0]
#  [ 1  0  6  5  0  0]
#  [ 2  7 91 32  3  0]
#  [ 0  3 43 66 21  1]
#  [ 0  0  6 13 13  1]
#  [ 0  0  0  2  2  0]]
#              precision    recall  f1-score   support
#
#           3       0.25      0.50      0.33         2
#           4       0.00      0.00      0.00        12
#           5       0.62      0.67      0.65       135
#           6       0.56      0.49      0.52       134
#           7       0.33      0.39      0.36        33
#           8       0.00      0.00      0.00         4
#
# avg / total       0.53      0.53      0.53       320

# %% [markdown]
# Erkenntnisse:
# - Naive Bayes benötigt keine Normalisierung, die Ergebnisse bleiben gleich

# %% [markdown]
# ### Feature experiments: Correlation multiplications

# %%
from sklearn.model_selection import train_test_split  
train_data1, test_data1, train_label1, test_label1 = train_test_split(data_multiplied, label_multiplied, test_size=0.10)

# %%
from sklearn.naive_bayes import GaussianNB

model1 = GaussianNB().fit(train_data1, train_label1)

# %%
prediction_test1 = model1.predict(test_data1)

print(np.mean(prediction_test1 == test_label1))
# Out:
# 0.5625

# %%
from sklearn.metrics import classification_report, confusion_matrix  
print(confusion_matrix(test_label1, prediction_test1))  
print(classification_report(test_label1, prediction_test1))
# Out:
# [[ 0  1  0  1  0  0]
#  [ 0  1  1  0  0  0]
#  [ 1  6 49  9  1  0]
#  [ 1  3 15 35  1  7]
#  [ 0  1  1 11  5  7]
#  [ 0  0  0  2  1  0]]
#              precision    recall  f1-score   support
#
#           3       0.00      0.00      0.00         2
#           4       0.08      0.50      0.14         2
#           5       0.74      0.74      0.74        66
#           6       0.60      0.56      0.58        62
#           7       0.62      0.20      0.30        25
#           8       0.00      0.00      0.00         3
#
# avg / total       0.64      0.56      0.58       160

# %% [markdown]
# Um sagen zu können, ob der Classifier mit ausgewählten features besser funktioniert, müsste man die selben test, sowie trainingsdaten verwenden --> Nochmal probieren

# %% [markdown]
# ### Feature experiments: Distance from mean

# %%
from sklearn.model_selection import train_test_split  
train_data2, test_data2, train_label2, test_label2 = train_test_split(data_mean, label_mean, test_size=0.10)

# %%
from sklearn.naive_bayes import GaussianNB

model2 = GaussianNB().fit(train_data2, train_label2)

# %%
prediction_test2 = model2.predict(test_data2)

print(np.mean(prediction_test2 == test_label2))
# Out:
# 0.48125

# %%
from sklearn.metrics import classification_report, confusion_matrix  
print(confusion_matrix(test_label2, prediction_test2))  
print(classification_report(test_label2, prediction_test2))
# Out:
# [[ 1  0  0  0  0  0]
#  [ 1  0  2  2  0  0]
#  [ 0  4 31 21  4  0]
#  [ 1  6 13 36  5  4]
#  [ 0  0  2 11  9  3]
#  [ 0  0  0  0  4  0]]
#              precision    recall  f1-score   support
#
#           3       0.33      1.00      0.50         1
#           4       0.00      0.00      0.00         5
#           5       0.65      0.52      0.57        60
#           6       0.51      0.55      0.53        65
#           7       0.41      0.36      0.38        25
#           8       0.00      0.00      0.00         4
#
# avg / total       0.52      0.48      0.49       160

# %% [markdown]
# ## With other classes

# %%
from sklearn.model_selection import train_test_split  
train_data3, test_data3, train_label3, test_label3 = train_test_split(data_class, label_class, test_size=0.20)

# %%
from sklearn.naive_bayes import GaussianNB

model3 = GaussianNB().fit(train_data3, train_label3)

# %%
prediction_test3 = model3.predict(test_data3)

print(np.mean(prediction_test3 == test_label3))
# Out:
# 0.8875

# %%
from sklearn.metrics import classification_report, confusion_matrix  
print(confusion_matrix(test_label3, prediction_test3))  
print(classification_report(test_label3, prediction_test3))
# Out:
# [[  0  13   0]
#  [ 11 284   9]
#  [  0   3   0]]
#              precision    recall  f1-score   support
#
#     1 - low       0.00      0.00      0.00        13
#  2 - middle       0.95      0.93      0.94       304
#    3 - high       0.00      0.00      0.00         3
#
# avg / total       0.90      0.89      0.89       320

# %% [markdown]
# ## Stratified k-fold Cross-Validation

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_predict
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.model_selection import LeaveOneOut
from sklearn.cross_validation import KFold, cross_val_score

from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels
def confusion_matrix_report(y_true, y_pred):    
    cm, labels = confusion_matrix(y_true, y_pred), unique_labels(y_true, y_pred)
    column_width = max([len(str(x)) for x in labels] + [5])  # 5 is value length
    report = " " * column_width + " " + "{:_^{}}".format("Prediction", column_width * len(labels))+ "\n"
    report += " " * column_width + " ".join(["{:>{}}".format(label, column_width) for label in labels]) + "\n"
    for i, label1 in enumerate(labels):
        report += "{:>{}}".format(label1, column_width) + " ".join(["{:{}d}".format(cm[i, j], column_width) for j in range(len(labels))]) + "\n"
    return report
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
cross_val = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
prediction_val = cross_val_predict(model, data_normal, label_normal, cv=10)

print(confusion_matrix_report(label_normal, prediction_val))
print(accuracy_score(label_normal, prediction_val))
print(classification_report(label_normal, prediction_val))
# Out:
#       __________Prediction__________
#          3     4     5     6     7     8
#     3    0     4     4     2     0     0
#     4    2     5    30    14     1     1
#     5    4    32   444   178    23     0
#     6    0    22   188   315   109     4
#     7    0     1    11    79   105     3
#     8    0     0     0     6    12     0
#
# 0.5434646654158849
#              precision    recall  f1-score   support
#
#           3       0.00      0.00      0.00        10
#           4       0.08      0.09      0.09        53
#           5       0.66      0.65      0.65       681
#           6       0.53      0.49      0.51       638
#           7       0.42      0.53      0.47       199
#           8       0.00      0.00      0.00        18
#
# avg / total       0.55      0.54      0.54      1599

# %%
k_fold = KFold(len(label_normal), shuffle=True, random_state=0)
clf = GaussianNB()

prediction_val = cross_val_predict(clf, data_normal, label_normal, cv=k_fold, n_jobs=1)

print(confusion_matrix_report(label_normal, prediction_val))
print(accuracy_score(label_normal, prediction_val))
print(classification_report(label_normal, prediction_val))
# Out:
#       __________Prediction__________
#          3     4     5     6     7     8
#     3    2     1     6     1     0     0
#     4    2     7    26    17     1     0
#     5    7    27   451   168    27     1
#     6    2    26   180   315   105    10
#     7    1     2    15    73   100     8
#     8    0     0     0     5    12     1
#
# 0.5478424015009381
#              precision    recall  f1-score   support
#
#           3       0.14      0.20      0.17        10
#           4       0.11      0.13      0.12        53
#           5       0.67      0.66      0.66       681
#           6       0.54      0.49      0.52       638
#           7       0.41      0.50      0.45       199
#           8       0.05      0.06      0.05        18
#
# avg / total       0.56      0.55      0.55      1599

# %% [markdown]
# red.info()
